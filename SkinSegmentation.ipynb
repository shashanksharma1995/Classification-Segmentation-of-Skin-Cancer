# %%
import keras 
import numpy as n
import pandas as p
import cv2 as c
import os
import matplotlib.pyplot as plt

# %%
im = c.imread('C:/Users/mayan/BTP/Skin-cancer-lesion-detection-master/images/ISIC_0024343.jpg')

# %%
im_gray = c.cvtColor(im,c.COLOR_BGR2GRAY)

# %%
plt.imshow(im)
plt.show()

# %%
ret,gray = c.threshold(im,135,256,c.THRESH_BINARY)

# %%
plt.imshow(gray)
plt.show()

# %%
im2 = c.imread('C:/Users/mayan/BTP/Skin-cancer-lesion-detection-master/images/ISIC_0024343.jpg',0)

# %%
plt.imshow(im2)
plt.show()

# %%
ret,gray = c.threshold(im2,135,256,c.THRESH_BINARY)

# %%
plt.imshow(gray)
plt.show()
